# %%
import pandas as pd
import numpy as np
import numpy.random as nr

# %%
document1 = {0: [['lawang-sewu/NN', 0.09],
                 ['lantai/NN', 0.07],
                 ['bawah/NN', 0.07],
                 ['tanah/NN', 0.07],
                 ['aula/NN', 0.04],
                 ['pendingin/NN', 0.02],
                 ['air/NN', 0.02],
                 ['memiliki/VBT', 0.02],
                 ['terdapat/VBT', 0.01]],
             1: [['lawang-sewu/NN', 0.08],
                 ['landmark/NN', 0.07],
                 ['semarang/NN', 0.07],
                 ['jalan/NN', 0.03],
                 ['pemuda/NN', 0.03],
                 ['pertempuran/NN', 0.01],
                 ['menjadi/VBT', 0.01],
                 ['lokasi/NN', 0.01],
                 ['hebat/JJ', 0.01]]}

# %%
document = document1

# %% [markdown]
# # Grammar

# %%
import re, random
from collections import OrderedDict, defaultdict

# %%
NP = ['_NN', '_NN _JJ', '_NN _SC _JJ', '_NNG', '_NNP', '_NP _PP']
VP = ['_VBT _NN', '_VBT _NN _NN', '_VBT _NN _CC _NN', '_VBT _NP', '_VBI', '_JJ']

# %%
def get_list_tag(dict_words_by_tag):
    result = []
    for key in dict_words_by_tag:
        result.append(key)
    return result

# %%
def generate_base_grammar(list_tag):
    result = {}
    
    if '_VBT' not in list_tag:
        list_tag.append('_VBT')
    
    S = {"_S": ["_NP _VP"]}
    PP = {"_PP": ["_IN _NP"]}
    
    if '_JJ' in list_tag:
        NP_RULES = generate_NP(list_tag)
        NP = {"_NP": NP_RULES}
        if check_VP(list_tag):
            VP_RULES = ['_PP', '_JJ'] + generate_VP(list_tag)
            VP = {"_VP": VP_RULES}
        else:
            VP = {"_VP": ['_PP', '_JJ']}

        for r in [S, NP, VP, PP]:
            result.update(r)
        return result
    else:
        NP_RULES = remove_JJ(generate_NP(list_tag))
        NP = {"_NP": NP_RULES}
        if check_VP(list_tag):
            VP_RULES = ['_PP'] + remove_JJ(generate_VP(list_tag))
            VP = {"_VP": VP_RULES}
        else:
            VP = {"_VP": ['_PP']}
            
        for r in [S, NP, VP, PP]:
            result.update(r)
        return result

def generate_NP(list_tag):
    result = []
    for tag in list_tag:
        for words in NP:
            if re.search(r'\b' + tag + r'\b', words):
                result.append(words)
    return list(OrderedDict.fromkeys(result))
    
def check_VP(list_tag):
    for tag in list_tag:
        if 'V' in tag:
            return True
    return False

def generate_VP(list_tag):
    result = []
    for tag in list_tag:
        for words in VP:
            if re.search(r'\b' + tag + r'\b', words):
                result.append(words)
    return list(OrderedDict.fromkeys(result))

def remove_JJ(list_tag):
    result = []
    for tag in list_tag:
        if '_JJ' in tag:
            continue
        else:
            result.append(tag)
    return result

# %%
def generate_words_grammar(dict_words_by_tag):
    result = {}
    IN = {"_IN": ['di', 'sebagai']}
    CC = {"_CC": ['dan']}
    SC = {"_SC": ['yang']}
    ADD_VBT = {"_VBT": ['memiliki', 'adalah', 'merupakan', 'terdapat', 'yaitu', 'sebagai', 'mempunyai']}
    
    WORDS = dict_words_by_tag
    if '_VBT' in WORDS:
        for word in ADD_VBT["_VBT"]:
            if word not in WORDS['_VBT']:
                WORDS['_VBT'].append(word)
    else:
        WORDS.update(ADD_VBT)
            
    for r in [IN, CC, SC, WORDS]:
        result.update(r)
    return result

# %%
def organize_words_by_tag(list_words):
    result = defaultdict(list)
    
    i = []
    for s in list_words:
        word, pwz = s[0], s[1]
        
        wrd = word.split('/')[0]
        tag = word.split('/')[1]
        result['_'+tag].append([wrd, pwz])
    return dict(result)

# %%
def split_word_pwz(dict_words_pwz_by_tag):
    dict_word_by_tag = defaultdict(list)
    dict_pwz_by_tag = defaultdict(list)
    
    for key, values in dict_words_pwz_by_tag.items():
        for data in values:
            word, pwz = data[0], data[1]
            dict_word_by_tag[key].append(word)
            dict_pwz_by_tag[key].append(pwz)
    return dict(dict_word_by_tag), dict(dict_pwz_by_tag)

# %%
def create_grammar(dict_words_by_topic):
    grammar = {}
    
    dict_words_pwz_by_tag = organize_words_by_tag(dict_words_by_topic)
    list_tag = get_list_tag(dict_words_pwz_by_tag)
    base_grammar = generate_base_grammar(list_tag)
    dict_word_by_tag, dict_pwz_by_tag = split_word_pwz(dict_words_pwz_by_tag)
    words_grammar = generate_words_grammar(dict_word_by_tag)
    
    for r in [base_grammar, words_grammar]:
        grammar.update(r)
    return grammar, dict_pwz_by_tag

# %%
def merge_two_dicts(x, y):
    z = x.copy()
    z.update(y)
    return z

# %%
def is_terminal(token):
    return token[0] != "_"

# %%
sys_random = random.SystemRandom()

def expand(grammar, tokens, dict_pwz_by_tag):
    print(tokens)
    for i, token in enumerate(tokens):

        # skip over terminals
        if is_terminal(token): continue

        # if we get here, we found a non-terminal token
        # so we need to choose a replacement at random
        replacement = random.choice(grammar[token])
        
        if replacement == '_NN':
            weight = [x/sum(dict_pwz_by_tag['_NN']) for x in dict_pwz_by_tag['_NN']]
            print(weight)
            replacement = nr.choice(grammar['_NN'], p=weight)
            
        if is_terminal(replacement):
            tokens[i] = replacement
        else:
            tokens = tokens[:i] + replacement.split() + tokens[(i+1):]
       
        # now call expand on the new list of tokens
        return expand(grammar, tokens, dict_pwz_by_tag)

    # if we get here we had all terminals and are done
    return tokens

# %%
def generate_sentence(grammar, dict_pwz_by_tag):
    return expand(grammar, ["_S"], dict_pwz_by_tag)

# %%
def create_sentences_from_data(dict_data):
    result = {}
    for topic, words in dict_data.items():
        sentence = []
        grammar, dict_pwz_by_tag = create_grammar(words)
        print(grammar)
        for s in range(100):
            sentence.append(' '.join(generate_sentence(grammar, dict_pwz_by_tag)))
        result = merge_two_dicts(result, {topic: sentence})
    return result

# %%
dict_story = create_sentences_from_data(document)
# Out:
# {'_S': ['_NP _VP'], '_NP': ['_NN'], '_VP': ['_PP', '_VBT _NN', '_VBT _NN _NN', '_VBT _NN _CC _NN', '_VBT _NP'], '_PP': ['_IN _NP'], '_IN': ['di', 'sebagai'], '_CC': ['dan'], '_SC': ['yang'], '_NN': ['lawang-sewu', 'lantai', 'bawah', 'tanah', 'aula', 'pendingin', 'air'], '_VBT': ['memiliki', 'terdapat', 'adalah', 'merupakan', 'yaitu', 'sebagai', 'mempunyai']}
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NN', '_NN']
# ['bawah', 'memiliki', '_NN', '_NN']
# ['bawah', 'memiliki', 'aula', '_NN']
# ['bawah', 'memiliki', 'aula', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NP']
# ['lawang-sewu', 'yaitu', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', 'yaitu', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN', '_CC', '_NN']
# ['lantai', 'yaitu', '_NN', '_CC', '_NN']
# ['lantai', 'yaitu', 'tanah', '_CC', '_NN']
# ['lantai', 'yaitu', 'tanah', 'dan', '_NN']
# ['lantai', 'yaitu', 'tanah', 'dan', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_PP']
# ['lantai', '_IN', '_NP']
# ['lantai', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', 'di', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', '_VP']
# ['aula', '_PP']
# ['aula', '_IN', '_NP']
# ['aula', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', 'di', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_PP']
# ['bawah', '_IN', '_NP']
# ['bawah', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', 'di', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'mempunyai', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'mempunyai', 'lantai', '_CC', '_NN']
# ['lawang-sewu', 'mempunyai', 'lantai', 'dan', '_NN']
# ['lawang-sewu', 'mempunyai', 'lantai', 'dan', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NP']
# ['tanah', 'sebagai', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', 'sebagai', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN', '_CC', '_NN']
# ['tanah', 'terdapat', '_NN', '_CC', '_NN']
# ['tanah', 'terdapat', 'tanah', '_CC', '_NN']
# ['tanah', 'terdapat', 'tanah', 'dan', '_NN']
# ['tanah', 'terdapat', 'tanah', 'dan', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NP']
# ['lawang-sewu', 'adalah', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', 'adalah', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN', '_CC', '_NN']
# ['tanah', 'memiliki', '_NN', '_CC', '_NN']
# ['tanah', 'memiliki', 'bawah', '_CC', '_NN']
# ['tanah', 'memiliki', 'bawah', 'dan', '_NN']
# ['tanah', 'memiliki', 'bawah', 'dan', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['pendingin', '_VP']
# ['pendingin', '_VBT', '_NN', '_NN']
# ['pendingin', 'merupakan', '_NN', '_NN']
# ['pendingin', 'merupakan', 'bawah', '_NN']
# ['pendingin', 'merupakan', 'bawah', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN']
# ['tanah', 'sebagai', '_NN']
# ['tanah', 'sebagai', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NN', '_CC', '_NN']
# ['bawah', 'terdapat', '_NN', '_CC', '_NN']
# ['bawah', 'terdapat', 'air', '_CC', '_NN']
# ['bawah', 'terdapat', 'air', 'dan', '_NN']
# ['bawah', 'terdapat', 'air', 'dan', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', '_VP']
# ['aula', '_VBT', '_NP']
# ['aula', 'merupakan', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', 'merupakan', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', '_VP']
# ['aula', '_VBT', '_NN', '_CC', '_NN']
# ['aula', 'adalah', '_NN', '_CC', '_NN']
# ['aula', 'adalah', 'lawang-sewu', '_CC', '_NN']
# ['aula', 'adalah', 'lawang-sewu', 'dan', '_NN']
# ['aula', 'adalah', 'lawang-sewu', 'dan', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'terdapat', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'terdapat', 'bawah', '_CC', '_NN']
# ['lawang-sewu', 'terdapat', 'bawah', 'dan', '_NN']
# ['lawang-sewu', 'terdapat', 'bawah', 'dan', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NP']
# ['lantai', 'yaitu', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', 'yaitu', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN', '_NN']
# ['tanah', 'terdapat', '_NN', '_NN']
# ['tanah', 'terdapat', 'pendingin', '_NN']
# ['tanah', 'terdapat', 'pendingin', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_PP']
# ['lawang-sewu', '_IN', '_NP']
# ['lawang-sewu', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', 'di', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN']
# ['tanah', 'adalah', '_NN']
# ['tanah', 'adalah', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_PP']
# ['tanah', '_IN', '_NP']
# ['tanah', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', 'di', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['pendingin', '_VP']
# ['pendingin', '_VBT', '_NN', '_CC', '_NN']
# ['pendingin', 'merupakan', '_NN', '_CC', '_NN']
# ['pendingin', 'merupakan', 'lantai', '_CC', '_NN']
# ['pendingin', 'merupakan', 'lantai', 'dan', '_NN']
# ['pendingin', 'merupakan', 'lantai', 'dan', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NN']
# ['bawah', 'sebagai', '_NN']
# ['bawah', 'sebagai', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['pendingin', '_VP']
# ['pendingin', '_PP']
# ['pendingin', '_IN', '_NP']
# ['pendingin', 'sebagai', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['pendingin', 'sebagai', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NP']
# ['bawah', 'yaitu', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', 'yaitu', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN', '_CC', '_NN']
# ['lantai', 'yaitu', '_NN', '_CC', '_NN']
# ['lantai', 'yaitu', 'tanah', '_CC', '_NN']
# ['lantai', 'yaitu', 'tanah', 'dan', '_NN']
# ['lantai', 'yaitu', 'tanah', 'dan', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN', '_NN']
# ['lantai', 'terdapat', '_NN', '_NN']
# ['lantai', 'terdapat', 'tanah', '_NN']
# ['lantai', 'terdapat', 'tanah', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_PP']
# ['bawah', '_IN', '_NP']
# ['bawah', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', 'di', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_PP']
# ['tanah', '_IN', '_NP']
# ['tanah', 'sebagai', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', 'sebagai', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NP']
# ['lawang-sewu', 'memiliki', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', 'memiliki', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NP']
# ['lantai', 'mempunyai', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', 'mempunyai', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NN']
# ['bawah', 'mempunyai', '_NN']
# ['bawah', 'mempunyai', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NN', '_NN']
# ['bawah', 'yaitu', '_NN', '_NN']
# ['bawah', 'yaitu', 'bawah', '_NN']
# ['bawah', 'yaitu', 'bawah', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN']
# ['tanah', 'terdapat', '_NN']
# ['tanah', 'terdapat', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN']
# ['tanah', 'sebagai', '_NN']
# ['tanah', 'sebagai', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NN', '_NN']
# ['lawang-sewu', 'adalah', '_NN', '_NN']
# ['lawang-sewu', 'adalah', 'aula', '_NN']
# ['lawang-sewu', 'adalah', 'aula', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN', '_NN']
# ['lantai', 'adalah', '_NN', '_NN']
# ['lantai', 'adalah', 'lantai', '_NN']
# ['lantai', 'adalah', 'lantai', 'pendingin']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NN']
# ['lawang-sewu', 'sebagai', '_NN']
# ['lawang-sewu', 'sebagai', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'terdapat', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'terdapat', 'lawang-sewu', '_CC', '_NN']
# ['lawang-sewu', 'terdapat', 'lawang-sewu', 'dan', '_NN']
# ['lawang-sewu', 'terdapat', 'lawang-sewu', 'dan', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['air', '_VP']
# ['air', '_VBT', '_NN', '_CC', '_NN']
# ['air', 'adalah', '_NN', '_CC', '_NN']
# ['air', 'adalah', 'lawang-sewu', '_CC', '_NN']
# ['air', 'adalah', 'lawang-sewu', 'dan', '_NN']
# ['air', 'adalah', 'lawang-sewu', 'dan', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN', '_CC', '_NN']
# ['tanah', 'yaitu', '_NN', '_CC', '_NN']
# ['tanah', 'yaitu', 'tanah', '_CC', '_NN']
# ['tanah', 'yaitu', 'tanah', 'dan', '_NN']
# ['tanah', 'yaitu', 'tanah', 'dan', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['air', '_VP']
# ['air', '_VBT', '_NN', '_NN']
# ['air', 'yaitu', '_NN', '_NN']
# ['air', 'yaitu', 'lawang-sewu', '_NN']
# ['air', 'yaitu', 'lawang-sewu', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NP']
# ['tanah', 'mempunyai', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', 'mempunyai', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN', '_NN']
# ['lantai', 'mempunyai', '_NN', '_NN']
# ['lantai', 'mempunyai', 'lantai', '_NN']
# ['lantai', 'mempunyai', 'lantai', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN']
# ['tanah', 'memiliki', '_NN']
# ['tanah', 'memiliki', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', '_VP']
# ['aula', '_VBT', '_NN', '_NN']
# ['aula', 'adalah', '_NN', '_NN']
# ['aula', 'adalah', 'lantai', '_NN']
# ['aula', 'adalah', 'lantai', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', '_VP']
# ['aula', '_VBT', '_NP']
# ['aula', 'yaitu', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', 'yaitu', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NN', '_NN']
# ['lawang-sewu', 'sebagai', '_NN', '_NN']
# ['lawang-sewu', 'sebagai', 'air', '_NN']
# ['lawang-sewu', 'sebagai', 'air', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', '_VP']
# ['aula', '_VBT', '_NN', '_NN']
# ['aula', 'sebagai', '_NN', '_NN']
# ['aula', 'sebagai', 'lawang-sewu', '_NN']
# ['aula', 'sebagai', 'lawang-sewu', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_PP']
# ['bawah', '_IN', '_NP']
# ['bawah', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', 'di', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_PP']
# ['bawah', '_IN', '_NP']
# ['bawah', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', 'di', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NP']
# ['tanah', 'adalah', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', 'adalah', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NP']
# ['lantai', 'memiliki', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', 'memiliki', 'pendingin']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NP']
# ['tanah', 'terdapat', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', 'terdapat', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN']
# ['lantai', 'adalah', '_NN']
# ['lantai', 'adalah', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NN']
# ['lawang-sewu', 'merupakan', '_NN']
# ['lawang-sewu', 'merupakan', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NN']
# ['bawah', 'terdapat', '_NN']
# ['bawah', 'terdapat', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN', '_NN']
# ['tanah', 'mempunyai', '_NN', '_NN']
# ['tanah', 'mempunyai', 'bawah', '_NN']
# ['tanah', 'mempunyai', 'bawah', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'terdapat', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'terdapat', 'tanah', '_CC', '_NN']
# ['lawang-sewu', 'terdapat', 'tanah', 'dan', '_NN']
# ['lawang-sewu', 'terdapat', 'tanah', 'dan', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', '_VP']
# ['aula', '_VBT', '_NN']
# ['aula', 'merupakan', '_NN']
# ['aula', 'merupakan', 'pendingin']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_PP']
# ['tanah', '_IN', '_NP']
# ['tanah', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', 'di', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['pendingin', '_VP']
# ['pendingin', '_VBT', '_NN']
# ['pendingin', 'sebagai', '_NN']
# ['pendingin', 'sebagai', 'pendingin']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN', '_CC', '_NN']
# ['lantai', 'merupakan', '_NN', '_CC', '_NN']
# ['lantai', 'merupakan', 'pendingin', '_CC', '_NN']
# ['lantai', 'merupakan', 'pendingin', 'dan', '_NN']
# ['lantai', 'merupakan', 'pendingin', 'dan', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN', '_NN']
# ['lantai', 'merupakan', '_NN', '_NN']
# ['lantai', 'merupakan', 'air', '_NN']
# ['lantai', 'merupakan', 'air', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN', '_NN']
# ['tanah', 'mempunyai', '_NN', '_NN']
# ['tanah', 'mempunyai', 'lantai', '_NN']
# ['tanah', 'mempunyai', 'lantai', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_PP']
# ['lantai', '_IN', '_NP']
# ['lantai', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', 'di', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NN']
# ['bawah', 'mempunyai', '_NN']
# ['bawah', 'mempunyai', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['pendingin', '_VP']
# ['pendingin', '_PP']
# ['pendingin', '_IN', '_NP']
# ['pendingin', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['pendingin', 'di', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['pendingin', '_VP']
# ['pendingin', '_VBT', '_NN', '_CC', '_NN']
# ['pendingin', 'merupakan', '_NN', '_CC', '_NN']
# ['pendingin', 'merupakan', 'lantai', '_CC', '_NN']
# ['pendingin', 'merupakan', 'lantai', 'dan', '_NN']
# ['pendingin', 'merupakan', 'lantai', 'dan', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NN', '_NN']
# ['bawah', 'sebagai', '_NN', '_NN']
# ['bawah', 'sebagai', 'bawah', '_NN']
# ['bawah', 'sebagai', 'bawah', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN', '_CC', '_NN']
# ['lantai', 'merupakan', '_NN', '_CC', '_NN']
# ['lantai', 'merupakan', 'pendingin', '_CC', '_NN']
# ['lantai', 'merupakan', 'pendingin', 'dan', '_NN']
# ['lantai', 'merupakan', 'pendingin', 'dan', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN']
# ['tanah', 'terdapat', '_NN']
# ['tanah', 'terdapat', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['air', '_VP']
# ['air', '_VBT', '_NN']
# ['air', 'merupakan', '_NN']
# ['air', 'merupakan', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_PP']
# ['bawah', '_IN', '_NP']
# ['bawah', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', 'di', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN']
# ['tanah', 'mempunyai', '_NN']
# ['tanah', 'mempunyai', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN']
# ['tanah', 'mempunyai', '_NN']
# ['tanah', 'mempunyai', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', '_VP']
# ['aula', '_VBT', '_NN', '_CC', '_NN']
# ['aula', 'adalah', '_NN', '_CC', '_NN']
# ['aula', 'adalah', 'lawang-sewu', '_CC', '_NN']
# ['aula', 'adalah', 'lawang-sewu', 'dan', '_NN']
# ['aula', 'adalah', 'lawang-sewu', 'dan', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NN']
# ['bawah', 'terdapat', '_NN']
# ['bawah', 'terdapat', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN', '_NN']
# ['lantai', 'yaitu', '_NN', '_NN']
# ['lantai', 'yaitu', 'lantai', '_NN']
# ['lantai', 'yaitu', 'lantai', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN', '_NN']
# ['tanah', 'terdapat', '_NN', '_NN']
# ['tanah', 'terdapat', 'lawang-sewu', '_NN']
# ['tanah', 'terdapat', 'lawang-sewu', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN', '_CC', '_NN']
# ['lantai', 'adalah', '_NN', '_CC', '_NN']
# ['lantai', 'adalah', 'lawang-sewu', '_CC', '_NN']
# ['lantai', 'adalah', 'lawang-sewu', 'dan', '_NN']
# ['lantai', 'adalah', 'lawang-sewu', 'dan', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NN', '_NN']
# ['lawang-sewu', 'yaitu', '_NN', '_NN']
# ['lawang-sewu', 'yaitu', 'aula', '_NN']
# ['lawang-sewu', 'yaitu', 'aula', 'air']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_PP']
# ['lawang-sewu', '_IN', '_NP']
# ['lawang-sewu', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', 'di', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NN']
# ['tanah', 'terdapat', '_NN']
# ['tanah', 'terdapat', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', '_VP']
# ['aula', '_VBT', '_NN', '_NN']
# ['aula', 'sebagai', '_NN', '_NN']
# ['aula', 'sebagai', 'air', '_NN']
# ['aula', 'sebagai', 'air', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_PP']
# ['bawah', '_IN', '_NP']
# ['bawah', 'sebagai', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', 'sebagai', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NP']
# ['bawah', 'merupakan', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', 'merupakan', 'lantai']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', '_VP']
# ['aula', '_VBT', '_NP']
# ['aula', 'terdapat', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', 'terdapat', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NN', '_CC', '_NN']
# ['lantai', 'adalah', '_NN', '_CC', '_NN']
# ['lantai', 'adalah', 'bawah', '_CC', '_NN']
# ['lantai', 'adalah', 'bawah', 'dan', '_NN']
# ['lantai', 'adalah', 'bawah', 'dan', 'aula']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['bawah', '_VP']
# ['bawah', '_VBT', '_NN', '_CC', '_NN']
# ['bawah', 'sebagai', '_NN', '_CC', '_NN']
# ['bawah', 'sebagai', 'pendingin', '_CC', '_NN']
# ['bawah', 'sebagai', 'pendingin', 'dan', '_NN']
# ['bawah', 'sebagai', 'pendingin', 'dan', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NP']
# ['tanah', 'mempunyai', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', 'mempunyai', 'bawah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'memiliki', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'memiliki', 'aula', '_CC', '_NN']
# ['lawang-sewu', 'memiliki', 'aula', 'dan', '_NN']
# ['lawang-sewu', 'memiliki', 'aula', 'dan', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', '_VP']
# ['tanah', '_VBT', '_NP']
# ['tanah', 'terdapat', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['tanah', 'terdapat', 'pendingin']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['air', '_VP']
# ['air', '_VBT', '_NP']
# ['air', 'mempunyai', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['air', 'mempunyai', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['air', '_VP']
# ['air', '_VBT', '_NN']
# ['air', 'merupakan', '_NN']
# ['air', 'merupakan', 'pendingin']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NP']
# ['lawang-sewu', 'yaitu', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', 'yaitu', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_PP']
# ['lawang-sewu', '_IN', '_NP']
# ['lawang-sewu', 'di', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lawang-sewu', 'di', 'tanah']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', '_VP']
# ['aula', '_VBT', '_NP']
# ['aula', 'merupakan', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['aula', 'merupakan', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', '_VP']
# ['lantai', '_VBT', '_NP']
# ['lantai', 'sebagai', '_NP']
# [0.23684210526315785, 0.18421052631578946, 0.18421052631578946, 0.18421052631578946, 0.10526315789473682, 0.05263157894736841, 0.05263157894736841]
# ['lantai', 'sebagai', 'bawah']
# {'_S': ['_NP _VP'], '_NP': ['_NN', '_NN _JJ', '_NN _SC _JJ'], '_VP': ['_PP', '_JJ', '_VBT _NN', '_VBT _NN _NN', '_VBT _NN _CC _NN', '_VBT _NP', '_JJ'], '_PP': ['_IN _NP'], '_IN': ['di', 'sebagai'], '_CC': ['dan'], '_SC': ['yang'], '_NN': ['lawang-sewu', 'landmark', 'semarang', 'jalan', 'pemuda', 'pertempuran', 'lokasi'], '_VBT': ['menjadi', 'memiliki', 'adalah', 'merupakan', 'terdapat', 'yaitu', 'sebagai', 'mempunyai'], '_JJ': ['hebat']}
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['lokasi', '_SC', '_JJ', '_VP']
# ['lokasi', 'yang', '_JJ', '_VP']
# ['lokasi', 'yang', 'hebat', '_VP']
# ['lokasi', 'yang', 'hebat', '_JJ']
# ['lokasi', 'yang', 'hebat', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['pertempuran', '_SC', '_JJ', '_VP']
# ['pertempuran', 'yang', '_JJ', '_VP']
# ['pertempuran', 'yang', 'hebat', '_VP']
# ['pertempuran', 'yang', 'hebat', '_VBT', '_NN', '_CC', '_NN']
# ['pertempuran', 'yang', 'hebat', 'terdapat', '_NN', '_CC', '_NN']
# ['pertempuran', 'yang', 'hebat', 'terdapat', 'pertempuran', '_CC', '_NN']
# ['pertempuran', 'yang', 'hebat', 'terdapat', 'pertempuran', 'dan', '_NN']
# ['pertempuran', 'yang', 'hebat', 'terdapat', 'pertempuran', 'dan', 'landmark']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['pemuda', '_VP']
# ['pemuda', '_VBT', '_NP']
# ['pemuda', 'terdapat', '_NP']
# ['pemuda', 'terdapat', '_NN', '_SC', '_JJ']
# ['pemuda', 'terdapat', 'jalan', '_SC', '_JJ']
# ['pemuda', 'terdapat', 'jalan', 'yang', '_JJ']
# ['pemuda', 'terdapat', 'jalan', 'yang', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['jalan', '_SC', '_JJ', '_VP']
# ['jalan', 'yang', '_JJ', '_VP']
# ['jalan', 'yang', 'hebat', '_VP']
# ['jalan', 'yang', 'hebat', '_VBT', '_NN', '_NN']
# ['jalan', 'yang', 'hebat', 'mempunyai', '_NN', '_NN']
# ['jalan', 'yang', 'hebat', 'mempunyai', 'pertempuran', '_NN']
# ['jalan', 'yang', 'hebat', 'mempunyai', 'pertempuran', 'landmark']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['semarang', '_JJ', '_VP']
# ['semarang', 'hebat', '_VP']
# ['semarang', 'hebat', '_PP']
# ['semarang', 'hebat', '_IN', '_NP']
# ['semarang', 'hebat', 'sebagai', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['semarang', 'hebat', 'sebagai', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['landmark', '_VP']
# ['landmark', '_VBT', '_NN']
# ['landmark', 'yaitu', '_NN']
# ['landmark', 'yaitu', 'lokasi']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['jalan', '_JJ', '_VP']
# ['jalan', 'hebat', '_VP']
# ['jalan', 'hebat', '_VBT', '_NN']
# ['jalan', 'hebat', 'mempunyai', '_NN']
# ['jalan', 'hebat', 'mempunyai', 'jalan']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['pertempuran', '_JJ', '_VP']
# ['pertempuran', 'hebat', '_VP']
# ['pertempuran', 'hebat', '_VBT', '_NP']
# ['pertempuran', 'hebat', 'merupakan', '_NP']
# ['pertempuran', 'hebat', 'merupakan', '_NN', '_JJ']
# ['pertempuran', 'hebat', 'merupakan', 'jalan', '_JJ']
# ['pertempuran', 'hebat', 'merupakan', 'jalan', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['jalan', '_SC', '_JJ', '_VP']
# ['jalan', 'yang', '_JJ', '_VP']
# ['jalan', 'yang', 'hebat', '_VP']
# ['jalan', 'yang', 'hebat', '_VBT', '_NN', '_NN']
# ['jalan', 'yang', 'hebat', 'mempunyai', '_NN', '_NN']
# ['jalan', 'yang', 'hebat', 'mempunyai', 'jalan', '_NN']
# ['jalan', 'yang', 'hebat', 'mempunyai', 'jalan', 'pertempuran']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['lokasi', '_VP']
# ['lokasi', '_PP']
# ['lokasi', '_IN', '_NP']
# ['lokasi', 'di', '_NP']
# ['lokasi', 'di', '_NN', '_JJ']
# ['lokasi', 'di', 'pertempuran', '_JJ']
# ['lokasi', 'di', 'pertempuran', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['pemuda', '_JJ', '_VP']
# ['pemuda', 'hebat', '_VP']
# ['pemuda', 'hebat', '_VBT', '_NN', '_NN']
# ['pemuda', 'hebat', 'sebagai', '_NN', '_NN']
# ['pemuda', 'hebat', 'sebagai', 'pemuda', '_NN']
# ['pemuda', 'hebat', 'sebagai', 'pemuda', 'semarang']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['semarang', '_SC', '_JJ', '_VP']
# ['semarang', 'yang', '_JJ', '_VP']
# ['semarang', 'yang', 'hebat', '_VP']
# ['semarang', 'yang', 'hebat', '_VBT', '_NP']
# ['semarang', 'yang', 'hebat', 'memiliki', '_NP']
# ['semarang', 'yang', 'hebat', 'memiliki', '_NN', '_SC', '_JJ']
# ['semarang', 'yang', 'hebat', 'memiliki', 'landmark', '_SC', '_JJ']
# ['semarang', 'yang', 'hebat', 'memiliki', 'landmark', 'yang', '_JJ']
# ['semarang', 'yang', 'hebat', 'memiliki', 'landmark', 'yang', 'hebat']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['pemuda', '_VP']
# ['pemuda', '_VBT', '_NN', '_NN']
# ['pemuda', 'adalah', '_NN', '_NN']
# ['pemuda', 'adalah', 'pertempuran', '_NN']
# ['pemuda', 'adalah', 'pertempuran', 'pertempuran']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['lokasi', '_SC', '_JJ', '_VP']
# ['lokasi', 'yang', '_JJ', '_VP']
# ['lokasi', 'yang', 'hebat', '_VP']
# ['lokasi', 'yang', 'hebat', '_VBT', '_NN', '_CC', '_NN']
# ['lokasi', 'yang', 'hebat', 'terdapat', '_NN', '_CC', '_NN']
# ['lokasi', 'yang', 'hebat', 'terdapat', 'pertempuran', '_CC', '_NN']
# ['lokasi', 'yang', 'hebat', 'terdapat', 'pertempuran', 'dan', '_NN']
# ['lokasi', 'yang', 'hebat', 'terdapat', 'pertempuran', 'dan', 'lokasi']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['lokasi', '_SC', '_JJ', '_VP']
# ['lokasi', 'yang', '_JJ', '_VP']
# ['lokasi', 'yang', 'hebat', '_VP']
# ['lokasi', 'yang', 'hebat', '_VBT', '_NP']
# ['lokasi', 'yang', 'hebat', 'memiliki', '_NP']
# ['lokasi', 'yang', 'hebat', 'memiliki', '_NN', '_JJ']
# ['lokasi', 'yang', 'hebat', 'memiliki', 'landmark', '_JJ']
# ['lokasi', 'yang', 'hebat', 'memiliki', 'landmark', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['lawang-sewu', '_SC', '_JJ', '_VP']
# ['lawang-sewu', 'yang', '_JJ', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_VBT', '_NN', '_NN']
# ['lawang-sewu', 'yang', 'hebat', 'yaitu', '_NN', '_NN']
# ['lawang-sewu', 'yang', 'hebat', 'yaitu', 'lawang-sewu', '_NN']
# ['lawang-sewu', 'yang', 'hebat', 'yaitu', 'lawang-sewu', 'landmark']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['lokasi', '_JJ', '_VP']
# ['lokasi', 'hebat', '_VP']
# ['lokasi', 'hebat', '_PP']
# ['lokasi', 'hebat', '_IN', '_NP']
# ['lokasi', 'hebat', 'di', '_NP']
# ['lokasi', 'hebat', 'di', '_NN', '_SC', '_JJ']
# ['lokasi', 'hebat', 'di', 'pertempuran', '_SC', '_JJ']
# ['lokasi', 'hebat', 'di', 'pertempuran', 'yang', '_JJ']
# ['lokasi', 'hebat', 'di', 'pertempuran', 'yang', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['semarang', '_SC', '_JJ', '_VP']
# ['semarang', 'yang', '_JJ', '_VP']
# ['semarang', 'yang', 'hebat', '_VP']
# ['semarang', 'yang', 'hebat', '_JJ']
# ['semarang', 'yang', 'hebat', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['pemuda', '_SC', '_JJ', '_VP']
# ['pemuda', 'yang', '_JJ', '_VP']
# ['pemuda', 'yang', 'hebat', '_VP']
# ['pemuda', 'yang', 'hebat', '_VBT', '_NP']
# ['pemuda', 'yang', 'hebat', 'yaitu', '_NP']
# ['pemuda', 'yang', 'hebat', 'yaitu', '_NN', '_JJ']
# ['pemuda', 'yang', 'hebat', 'yaitu', 'semarang', '_JJ']
# ['pemuda', 'yang', 'hebat', 'yaitu', 'semarang', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['lawang-sewu', '_SC', '_JJ', '_VP']
# ['lawang-sewu', 'yang', '_JJ', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_VBT', '_NP']
# ['lawang-sewu', 'yang', 'hebat', 'memiliki', '_NP']
# ['lawang-sewu', 'yang', 'hebat', 'memiliki', '_NN', '_JJ']
# ['lawang-sewu', 'yang', 'hebat', 'memiliki', 'landmark', '_JJ']
# ['lawang-sewu', 'yang', 'hebat', 'memiliki', 'landmark', 'hebat']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['jalan', '_VP']
# ['jalan', '_VBT', '_NP']
# ['jalan', 'merupakan', '_NP']
# ['jalan', 'merupakan', '_NN', '_JJ']
# ['jalan', 'merupakan', 'semarang', '_JJ']
# ['jalan', 'merupakan', 'semarang', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['semarang', '_SC', '_JJ', '_VP']
# ['semarang', 'yang', '_JJ', '_VP']
# ['semarang', 'yang', 'hebat', '_VP']
# ['semarang', 'yang', 'hebat', '_VBT', '_NP']
# ['semarang', 'yang', 'hebat', 'merupakan', '_NP']
# ['semarang', 'yang', 'hebat', 'merupakan', '_NN', '_JJ']
# ['semarang', 'yang', 'hebat', 'merupakan', 'lawang-sewu', '_JJ']
# ['semarang', 'yang', 'hebat', 'merupakan', 'lawang-sewu', 'hebat']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['landmark', '_VP']
# ['landmark', '_PP']
# ['landmark', '_IN', '_NP']
# ['landmark', 'di', '_NP']
# ['landmark', 'di', '_NN', '_SC', '_JJ']
# ['landmark', 'di', 'pertempuran', '_SC', '_JJ']
# ['landmark', 'di', 'pertempuran', 'yang', '_JJ']
# ['landmark', 'di', 'pertempuran', 'yang', 'hebat']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['semarang', '_VP']
# ['semarang', '_VBT', '_NN']
# ['semarang', 'sebagai', '_NN']
# ['semarang', 'sebagai', 'pertempuran']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['lawang-sewu', '_JJ', '_VP']
# ['lawang-sewu', 'hebat', '_VP']
# ['lawang-sewu', 'hebat', '_JJ']
# ['lawang-sewu', 'hebat', 'hebat']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_JJ']
# ['lawang-sewu', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ...
# ['lokasi', 'yang', 'hebat', 'adalah', 'landmark', 'yang', 'hebat']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['lawang-sewu', '_VP']
# ['lawang-sewu', '_VBT', '_NN']
# ['lawang-sewu', 'menjadi', '_NN']
# ['lawang-sewu', 'menjadi', 'jalan']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['lawang-sewu', '_JJ', '_VP']
# ['lawang-sewu', 'hebat', '_VP']
# ['lawang-sewu', 'hebat', '_VBT', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'hebat', 'menjadi', '_NN', '_CC', '_NN']
# ['lawang-sewu', 'hebat', 'menjadi', 'landmark', '_CC', '_NN']
# ['lawang-sewu', 'hebat', 'menjadi', 'landmark', 'dan', '_NN']
# ['lawang-sewu', 'hebat', 'menjadi', 'landmark', 'dan', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['jalan', '_SC', '_JJ', '_VP']
# ['jalan', 'yang', '_JJ', '_VP']
# ['jalan', 'yang', 'hebat', '_VP']
# ['jalan', 'yang', 'hebat', '_VBT', '_NN', '_NN']
# ['jalan', 'yang', 'hebat', 'yaitu', '_NN', '_NN']
# ['jalan', 'yang', 'hebat', 'yaitu', 'lawang-sewu', '_NN']
# ['jalan', 'yang', 'hebat', 'yaitu', 'lawang-sewu', 'pemuda']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['lawang-sewu', '_SC', '_JJ', '_VP']
# ['lawang-sewu', 'yang', '_JJ', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_JJ']
# ['lawang-sewu', 'yang', 'hebat', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['landmark', '_JJ', '_VP']
# ['landmark', 'hebat', '_VP']
# ['landmark', 'hebat', '_VBT', '_NN', '_CC', '_NN']
# ['landmark', 'hebat', 'adalah', '_NN', '_CC', '_NN']
# ['landmark', 'hebat', 'adalah', 'pertempuran', '_CC', '_NN']
# ['landmark', 'hebat', 'adalah', 'pertempuran', 'dan', '_NN']
# ['landmark', 'hebat', 'adalah', 'pertempuran', 'dan', 'semarang']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['pemuda', '_SC', '_JJ', '_VP']
# ['pemuda', 'yang', '_JJ', '_VP']
# ['pemuda', 'yang', 'hebat', '_VP']
# ['pemuda', 'yang', 'hebat', '_VBT', '_NN']
# ['pemuda', 'yang', 'hebat', 'menjadi', '_NN']
# ['pemuda', 'yang', 'hebat', 'menjadi', 'pemuda']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['pemuda', '_JJ', '_VP']
# ['pemuda', 'hebat', '_VP']
# ['pemuda', 'hebat', '_JJ']
# ['pemuda', 'hebat', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['pemuda', '_SC', '_JJ', '_VP']
# ['pemuda', 'yang', '_JJ', '_VP']
# ['pemuda', 'yang', 'hebat', '_VP']
# ['pemuda', 'yang', 'hebat', '_VBT', '_NN', '_NN']
# ['pemuda', 'yang', 'hebat', 'adalah', '_NN', '_NN']
# ['pemuda', 'yang', 'hebat', 'adalah', 'jalan', '_NN']
# ['pemuda', 'yang', 'hebat', 'adalah', 'jalan', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['landmark', '_SC', '_JJ', '_VP']
# ['landmark', 'yang', '_JJ', '_VP']
# ['landmark', 'yang', 'hebat', '_VP']
# ['landmark', 'yang', 'hebat', '_VBT', '_NN', '_NN']
# ['landmark', 'yang', 'hebat', 'yaitu', '_NN', '_NN']
# ['landmark', 'yang', 'hebat', 'yaitu', 'landmark', '_NN']
# ['landmark', 'yang', 'hebat', 'yaitu', 'landmark', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['landmark', '_VP']
# ['landmark', '_VBT', '_NN', '_NN']
# ['landmark', 'mempunyai', '_NN', '_NN']
# ['landmark', 'mempunyai', 'lawang-sewu', '_NN']
# ['landmark', 'mempunyai', 'lawang-sewu', 'semarang']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['semarang', '_VP']
# ['semarang', '_PP']
# ['semarang', '_IN', '_NP']
# ['semarang', 'sebagai', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['semarang', 'sebagai', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['landmark', '_SC', '_JJ', '_VP']
# ['landmark', 'yang', '_JJ', '_VP']
# ['landmark', 'yang', 'hebat', '_VP']
# ['landmark', 'yang', 'hebat', '_VBT', '_NN', '_CC', '_NN']
# ['landmark', 'yang', 'hebat', 'adalah', '_NN', '_CC', '_NN']
# ['landmark', 'yang', 'hebat', 'adalah', 'lokasi', '_CC', '_NN']
# ['landmark', 'yang', 'hebat', 'adalah', 'lokasi', 'dan', '_NN']
# ['landmark', 'yang', 'hebat', 'adalah', 'lokasi', 'dan', 'pertempuran']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['lawang-sewu', '_JJ', '_VP']
# ['lawang-sewu', 'hebat', '_VP']
# ['lawang-sewu', 'hebat', '_JJ']
# ['lawang-sewu', 'hebat', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['semarang', '_JJ', '_VP']
# ['semarang', 'hebat', '_VP']
# ['semarang', 'hebat', '_VBT', '_NN', '_CC', '_NN']
# ['semarang', 'hebat', 'terdapat', '_NN', '_CC', '_NN']
# ['semarang', 'hebat', 'terdapat', 'lokasi', '_CC', '_NN']
# ['semarang', 'hebat', 'terdapat', 'lokasi', 'dan', '_NN']
# ['semarang', 'hebat', 'terdapat', 'lokasi', 'dan', 'lokasi']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['pertempuran', '_JJ', '_VP']
# ['pertempuran', 'hebat', '_VP']
# ['pertempuran', 'hebat', '_JJ']
# ['pertempuran', 'hebat', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['pertempuran', '_SC', '_JJ', '_VP']
# ['pertempuran', 'yang', '_JJ', '_VP']
# ['pertempuran', 'yang', 'hebat', '_VP']
# ['pertempuran', 'yang', 'hebat', '_VBT', '_NN', '_CC', '_NN']
# ['pertempuran', 'yang', 'hebat', 'menjadi', '_NN', '_CC', '_NN']
# ['pertempuran', 'yang', 'hebat', 'menjadi', 'pemuda', '_CC', '_NN']
# ['pertempuran', 'yang', 'hebat', 'menjadi', 'pemuda', 'dan', '_NN']
# ['pertempuran', 'yang', 'hebat', 'menjadi', 'pemuda', 'dan', 'pemuda']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['lawang-sewu', '_SC', '_JJ', '_VP']
# ['lawang-sewu', 'yang', '_JJ', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_PP']
# ['lawang-sewu', 'yang', 'hebat', '_IN', '_NP']
# ['lawang-sewu', 'yang', 'hebat', 'sebagai', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['lawang-sewu', 'yang', 'hebat', 'sebagai', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['semarang', '_SC', '_JJ', '_VP']
# ['semarang', 'yang', '_JJ', '_VP']
# ['semarang', 'yang', 'hebat', '_VP']
# ['semarang', 'yang', 'hebat', '_VBT', '_NP']
# ['semarang', 'yang', 'hebat', 'merupakan', '_NP']
# ['semarang', 'yang', 'hebat', 'merupakan', '_NN', '_JJ']
# ['semarang', 'yang', 'hebat', 'merupakan', 'lawang-sewu', '_JJ']
# ['semarang', 'yang', 'hebat', 'merupakan', 'lawang-sewu', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['jalan', '_SC', '_JJ', '_VP']
# ['jalan', 'yang', '_JJ', '_VP']
# ['jalan', 'yang', 'hebat', '_VP']
# ['jalan', 'yang', 'hebat', '_VBT', '_NP']
# ['jalan', 'yang', 'hebat', 'merupakan', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['jalan', 'yang', 'hebat', 'merupakan', 'landmark']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['semarang', '_JJ', '_VP']
# ['semarang', 'hebat', '_VP']
# ['semarang', 'hebat', '_PP']
# ['semarang', 'hebat', '_IN', '_NP']
# ['semarang', 'hebat', 'di', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['semarang', 'hebat', 'di', 'landmark']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['landmark', '_JJ', '_VP']
# ['landmark', 'hebat', '_VP']
# ['landmark', 'hebat', '_JJ']
# ['landmark', 'hebat', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['lawang-sewu', '_JJ', '_VP']
# ['lawang-sewu', 'hebat', '_VP']
# ['lawang-sewu', 'hebat', '_VBT', '_NN', '_NN']
# ['lawang-sewu', 'hebat', 'yaitu', '_NN', '_NN']
# ['lawang-sewu', 'hebat', 'yaitu', 'landmark', '_NN']
# ['lawang-sewu', 'hebat', 'yaitu', 'landmark', 'pemuda']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['landmark', '_JJ', '_VP']
# ['landmark', 'hebat', '_VP']
# ['landmark', 'hebat', '_VBT', '_NP']
# ['landmark', 'hebat', 'merupakan', '_NP']
# ['landmark', 'hebat', 'merupakan', '_NN', '_JJ']
# ['landmark', 'hebat', 'merupakan', 'landmark', '_JJ']
# ['landmark', 'hebat', 'merupakan', 'landmark', 'hebat']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['semarang', '_VP']
# ['semarang', '_VBT', '_NN']
# ['semarang', 'mempunyai', '_NN']
# ['semarang', 'mempunyai', 'landmark']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['landmark', '_VP']
# ['landmark', '_VBT', '_NN', '_NN']
# ['landmark', 'mempunyai', '_NN', '_NN']
# ['landmark', 'mempunyai', 'pemuda', '_NN']
# ['landmark', 'mempunyai', 'pemuda', 'lokasi']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['pertempuran', '_SC', '_JJ', '_VP']
# ['pertempuran', 'yang', '_JJ', '_VP']
# ['pertempuran', 'yang', 'hebat', '_VP']
# ['pertempuran', 'yang', 'hebat', '_VBT', '_NN', '_CC', '_NN']
# ['pertempuran', 'yang', 'hebat', 'terdapat', '_NN', '_CC', '_NN']
# ['pertempuran', 'yang', 'hebat', 'terdapat', 'pertempuran', '_CC', '_NN']
# ['pertempuran', 'yang', 'hebat', 'terdapat', 'pertempuran', 'dan', '_NN']
# ['pertempuran', 'yang', 'hebat', 'terdapat', 'pertempuran', 'dan', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['lawang-sewu', '_JJ', '_VP']
# ['lawang-sewu', 'hebat', '_VP']
# ['lawang-sewu', 'hebat', '_JJ']
# ['lawang-sewu', 'hebat', 'hebat']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['pemuda', '_VP']
# ['pemuda', '_VBT', '_NN']
# ['pemuda', 'mempunyai', '_NN']
# ['pemuda', 'mempunyai', 'semarang']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['jalan', '_SC', '_JJ', '_VP']
# ['jalan', 'yang', '_JJ', '_VP']
# ['jalan', 'yang', 'hebat', '_VP']
# ['jalan', 'yang', 'hebat', '_VBT', '_NP']
# ['jalan', 'yang', 'hebat', 'memiliki', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['jalan', 'yang', 'hebat', 'memiliki', 'landmark']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['lawang-sewu', '_JJ', '_VP']
# ['lawang-sewu', 'hebat', '_VP']
# ['lawang-sewu', 'hebat', '_VBT', '_NP']
# ['lawang-sewu', 'hebat', 'menjadi', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['lawang-sewu', 'hebat', 'menjadi', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['jalan', '_JJ', '_VP']
# ['jalan', 'hebat', '_VP']
# ['jalan', 'hebat', '_PP']
# ['jalan', 'hebat', '_IN', '_NP']
# ['jalan', 'hebat', 'di', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['jalan', 'hebat', 'di', 'jalan']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['jalan', '_JJ', '_VP']
# ['jalan', 'hebat', '_VP']
# ['jalan', 'hebat', '_JJ']
# ['jalan', 'hebat', 'hebat']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['pemuda', '_VP']
# ['pemuda', '_VBT', '_NN', '_CC', '_NN']
# ['pemuda', 'adalah', '_NN', '_CC', '_NN']
# ['pemuda', 'adalah', 'lawang-sewu', '_CC', '_NN']
# ['pemuda', 'adalah', 'lawang-sewu', 'dan', '_NN']
# ['pemuda', 'adalah', 'lawang-sewu', 'dan', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['jalan', '_VP']
# ['jalan', '_VBT', '_NP']
# ['jalan', 'yaitu', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['jalan', 'yaitu', 'lawang-sewu']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['lawang-sewu', '_SC', '_JJ', '_VP']
# ['lawang-sewu', 'yang', '_JJ', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_PP']
# ['lawang-sewu', 'yang', 'hebat', '_IN', '_NP']
# ['lawang-sewu', 'yang', 'hebat', 'sebagai', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['lawang-sewu', 'yang', 'hebat', 'sebagai', 'semarang']
# ['_S']
# ['_NP', '_VP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['pertempuran', '_VP']
# ['pertempuran', '_PP']
# ['pertempuran', '_IN', '_NP']
# ['pertempuran', 'di', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['pertempuran', 'di', 'pemuda']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['pertempuran', '_JJ', '_VP']
# ['pertempuran', 'hebat', '_VP']
# ['pertempuran', 'hebat', '_VBT', '_NP']
# ['pertempuran', 'hebat', 'adalah', '_NP']
# ['pertempuran', 'hebat', 'adalah', '_NN', '_JJ']
# ['pertempuran', 'hebat', 'adalah', 'lawang-sewu', '_JJ']
# ['pertempuran', 'hebat', 'adalah', 'lawang-sewu', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['pertempuran', '_SC', '_JJ', '_VP']
# ['pertempuran', 'yang', '_JJ', '_VP']
# ['pertempuran', 'yang', 'hebat', '_VP']
# ['pertempuran', 'yang', 'hebat', '_JJ']
# ['pertempuran', 'yang', 'hebat', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['lawang-sewu', '_SC', '_JJ', '_VP']
# ['lawang-sewu', 'yang', '_JJ', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_VP']
# ['lawang-sewu', 'yang', 'hebat', '_VBT', '_NN', '_NN']
# ['lawang-sewu', 'yang', 'hebat', 'terdapat', '_NN', '_NN']
# ['lawang-sewu', 'yang', 'hebat', 'terdapat', 'landmark', '_NN']
# ['lawang-sewu', 'yang', 'hebat', 'terdapat', 'landmark', 'lokasi']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['lokasi', '_SC', '_JJ', '_VP']
# ['lokasi', 'yang', '_JJ', '_VP']
# ['lokasi', 'yang', 'hebat', '_VP']
# ['lokasi', 'yang', 'hebat', '_VBT', '_NP']
# ['lokasi', 'yang', 'hebat', 'memiliki', '_NP']
# ['lokasi', 'yang', 'hebat', 'memiliki', '_NN', '_JJ']
# ['lokasi', 'yang', 'hebat', 'memiliki', 'pemuda', '_JJ']
# ['lokasi', 'yang', 'hebat', 'memiliki', 'pemuda', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['semarang', '_JJ', '_VP']
# ['semarang', 'hebat', '_VP']
# ['semarang', 'hebat', '_VBT', '_NP']
# ['semarang', 'hebat', 'menjadi', '_NP']
# ['semarang', 'hebat', 'menjadi', '_NN', '_SC', '_JJ']
# ['semarang', 'hebat', 'menjadi', 'jalan', '_SC', '_JJ']
# ['semarang', 'hebat', 'menjadi', 'jalan', 'yang', '_JJ']
# ['semarang', 'hebat', 'menjadi', 'jalan', 'yang', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['semarang', '_SC', '_JJ', '_VP']
# ['semarang', 'yang', '_JJ', '_VP']
# ['semarang', 'yang', 'hebat', '_VP']
# ['semarang', 'yang', 'hebat', '_PP']
# ['semarang', 'yang', 'hebat', '_IN', '_NP']
# ['semarang', 'yang', 'hebat', 'sebagai', '_NP']
# [0.2666666666666666, 0.2333333333333333, 0.2333333333333333, 0.09999999999999998, 0.09999999999999998, 0.033333333333333326, 0.033333333333333326]
# ['semarang', 'yang', 'hebat', 'sebagai', 'landmark']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_SC', '_JJ', '_VP']
# ['landmark', '_SC', '_JJ', '_VP']
# ['landmark', 'yang', '_JJ', '_VP']
# ['landmark', 'yang', 'hebat', '_VP']
# ['landmark', 'yang', 'hebat', '_PP']
# ['landmark', 'yang', 'hebat', '_IN', '_NP']
# ['landmark', 'yang', 'hebat', 'di', '_NP']
# ['landmark', 'yang', 'hebat', 'di', '_NN', '_SC', '_JJ']
# ['landmark', 'yang', 'hebat', 'di', 'pemuda', '_SC', '_JJ']
# ['landmark', 'yang', 'hebat', 'di', 'pemuda', 'yang', '_JJ']
# ['landmark', 'yang', 'hebat', 'di', 'pemuda', 'yang', 'hebat']
# ['_S']
# ['_NP', '_VP']
# ['_NN', '_JJ', '_VP']
# ['jalan', '_JJ', '_VP']
# ['jalan', 'hebat', '_VP']
# ['jalan', 'hebat', '_VBT', '_NN', '_NN']
# ['jalan', 'hebat', 'sebagai', '_NN', '_NN']
# ['jalan', 'hebat', 'sebagai', 'lawang-sewu', '_NN']
# ['jalan', 'hebat', 'sebagai', 'lawang-sewu', 'pemuda']

# %%
dict_story
# Out:
# {0: ['bawah memiliki aula lantai',
#   'lawang-sewu yaitu bawah',
#   'lantai yaitu tanah dan lawang-sewu',
#   'lantai di air',
#   'aula di air',
#   'bawah di lantai',
#   'lawang-sewu mempunyai lantai dan lantai',
#   'tanah sebagai lawang-sewu',
#   'tanah terdapat tanah dan lantai',
#   'lawang-sewu adalah lantai',
#   'tanah memiliki bawah dan aula',
#   'pendingin merupakan bawah lantai',
#   'tanah sebagai bawah',
#   'bawah terdapat air dan lawang-sewu',
#   'aula merupakan tanah',
#   'aula adalah lawang-sewu dan lantai',
#   'lawang-sewu terdapat bawah dan bawah',
#   'lantai yaitu bawah',
#   'tanah terdapat pendingin air',
#   'lawang-sewu di lawang-sewu',
#   'tanah adalah bawah',
#   'tanah di bawah',
#   'pendingin merupakan lantai dan air',
#   'bawah sebagai tanah',
#   'pendingin sebagai aula',
#   'bawah yaitu bawah',
#   'lantai yaitu tanah dan lantai',
#   'lantai terdapat tanah aula',
#   'bawah di lawang-sewu',
#   'tanah sebagai lantai',
#   'lawang-sewu memiliki lantai',
#   'lantai mempunyai lantai',
#   'bawah mempunyai lantai',
#   'bawah yaitu bawah air',
#   'tanah terdapat tanah',
#   'tanah sebagai lantai',
#   'lawang-sewu adalah aula aula',
#   'lantai adalah lantai pendingin',
#   'lawang-sewu sebagai aula',
#   'lawang-sewu terdapat lawang-sewu dan bawah',
#   'air adalah lawang-sewu dan lawang-sewu',
#   'tanah yaitu tanah dan air',
#   'air yaitu lawang-sewu tanah',
#   'tanah mempunyai lawang-sewu',
#   'lantai mempunyai lantai tanah',
#   'tanah memiliki air',
#   'aula adalah lantai air',
#   'aula yaitu lawang-sewu',
#   'lawang-sewu sebagai air air',
#   'aula sebagai lawang-sewu lantai',
#   'bawah di tanah',
#   'bawah di bawah',
#   'tanah adalah tanah',
#   'lantai memiliki pendingin',
#   'tanah terdapat lantai',
#   'lantai adalah lawang-sewu',
#   'lawang-sewu merupakan tanah',
#   'bawah terdapat aula',
#   'tanah mempunyai bawah lantai',
#   'lawang-sewu terdapat tanah dan aula',
#   'aula merupakan pendingin',
#   'tanah di bawah',
#   'pendingin sebagai pendingin',
#   'lantai merupakan pendingin dan lantai',
#   'lantai merupakan air air',
#   'tanah mempunyai lantai aula',
#   'lantai di aula',
#   'bawah mempunyai aula',
#   'pendingin di bawah',
#   'pendingin merupakan lantai dan lawang-sewu',
#   'bawah sebagai bawah aula',
#   'lantai merupakan pendingin dan bawah',
#   'tanah terdapat aula',
#   'air merupakan lantai',
#   'bawah di tanah',
#   'tanah mempunyai aula',
#   'tanah mempunyai aula',
#   'aula adalah lawang-sewu dan bawah',
#   'bawah terdapat air',
#   'lantai yaitu lantai tanah',
#   'tanah terdapat lawang-sewu air',
#   'lantai adalah lawang-sewu dan bawah',
#   'lawang-sewu yaitu aula air',
#   'lawang-sewu di lawang-sewu',
#   'tanah terdapat lantai',
#   'aula sebagai air aula',
#   'bawah sebagai tanah',
#   'bawah merupakan lantai',
#   'aula terdapat tanah',
#   'lantai adalah bawah dan aula',
#   'bawah sebagai pendingin dan tanah',
#   'tanah mempunyai bawah',
#   'lawang-sewu memiliki aula dan lawang-sewu',
#   'tanah terdapat pendingin',
#   'air mempunyai tanah',
#   'air merupakan pendingin',
#   'lawang-sewu yaitu tanah',
#   'lawang-sewu di tanah',
#   'aula merupakan lawang-sewu',
#   'lantai sebagai bawah'],
#  1: ['lokasi yang hebat hebat',
#   'pertempuran yang hebat terdapat pertempuran dan landmark',
#   'pemuda terdapat jalan yang hebat',
#   'jalan yang hebat mempunyai pertempuran landmark',
#   'semarang hebat sebagai lawang-sewu',
#   'landmark yaitu lokasi',
#   'jalan hebat mempunyai jalan',
#   'pertempuran hebat merupakan jalan hebat',
#   'jalan yang hebat mempunyai jalan pertempuran',
#   'lokasi di pertempuran hebat',
#   'pemuda hebat sebagai pemuda semarang',
#   'semarang yang hebat memiliki landmark yang hebat',
#   'pemuda adalah pertempuran pertempuran',
#   'lokasi yang hebat terdapat pertempuran dan lokasi',
#   'lokasi yang hebat memiliki landmark hebat',
#   'lawang-sewu yang hebat yaitu lawang-sewu landmark',
#   'lokasi hebat di pertempuran yang hebat',
#   'semarang yang hebat hebat',
#   'pemuda yang hebat yaitu semarang hebat',
#   'lawang-sewu yang hebat memiliki landmark hebat',
#   'jalan merupakan semarang hebat',
#   'semarang yang hebat merupakan lawang-sewu hebat',
#   'landmark di pertempuran yang hebat',
#   'semarang sebagai pertempuran',
#   'lawang-sewu hebat hebat',
#   'lawang-sewu hebat',
#   'landmark hebat',
#   'jalan yang hebat hebat',
#   'lokasi yang hebat merupakan pemuda',
#   'pertempuran yang hebat hebat',
#   'pertempuran hebat terdapat landmark',
#   'landmark hebat sebagai landmark hebat',
#   'lawang-sewu yang hebat hebat',
#   'pemuda hebat',
#   'jalan yaitu lokasi dan jalan',
#   'semarang menjadi lawang-sewu jalan',
#   'lokasi hebat adalah lokasi dan lokasi',
#   'lawang-sewu hebat mempunyai pemuda lokasi',
#   'lawang-sewu hebat',
#   'lawang-sewu adalah lokasi',
#   'pertempuran hebat menjadi lawang-sewu pertempuran',
#   'lawang-sewu yang hebat merupakan pertempuran dan pertempuran',
#   'semarang hebat sebagai lawang-sewu',
#   'pertempuran yang hebat menjadi semarang lawang-sewu',
#   'landmark hebat sebagai pertempuran yang hebat',
#   'semarang merupakan pemuda',
#   'lokasi yang hebat hebat',
#   'lawang-sewu hebat yaitu jalan hebat',
#   'semarang yang hebat menjadi lokasi jalan',
#   'landmark yang hebat di pemuda hebat',
#   'lawang-sewu yang hebat hebat',
#   'lawang-sewu hebat mempunyai pertempuran dan semarang',
#   'pertempuran hebat sebagai lawang-sewu lawang-sewu',
#   'pertempuran hebat terdapat landmark pemuda',
#   'semarang hebat hebat',
#   'lokasi yang hebat adalah landmark yang hebat',
#   'lawang-sewu menjadi jalan',
#   'lawang-sewu hebat menjadi landmark dan lawang-sewu',
#   'jalan yang hebat yaitu lawang-sewu pemuda',
#   'lawang-sewu yang hebat hebat',
#   'landmark hebat adalah pertempuran dan semarang',
#   'pemuda yang hebat menjadi pemuda',
#   'pemuda hebat hebat',
#   'pemuda yang hebat adalah jalan lawang-sewu',
#   'landmark yang hebat yaitu landmark lawang-sewu',
#   'landmark mempunyai lawang-sewu semarang',
#   'semarang sebagai lawang-sewu',
#   'landmark yang hebat adalah lokasi dan pertempuran',
#   'lawang-sewu hebat hebat',
#   'semarang hebat terdapat lokasi dan lokasi',
#   'pertempuran hebat hebat',
#   'pertempuran yang hebat menjadi pemuda dan pemuda',
#   'lawang-sewu yang hebat sebagai lawang-sewu',
#   'semarang yang hebat merupakan lawang-sewu hebat',
#   'jalan yang hebat merupakan landmark',
#   'semarang hebat di landmark',
#   'landmark hebat hebat',
#   'lawang-sewu hebat yaitu landmark pemuda',
#   'landmark hebat merupakan landmark hebat',
#   'semarang mempunyai landmark',
#   'landmark mempunyai pemuda lokasi',
#   'pertempuran yang hebat terdapat pertempuran dan lawang-sewu',
#   'lawang-sewu hebat hebat',
#   'pemuda mempunyai semarang',
#   'jalan yang hebat memiliki landmark',
#   'lawang-sewu hebat menjadi lawang-sewu',
#   'jalan hebat di jalan',
#   'jalan hebat hebat',
#   'pemuda adalah lawang-sewu dan lawang-sewu',
#   'jalan yaitu lawang-sewu',
#   'lawang-sewu yang hebat sebagai semarang',
#   'pertempuran di pemuda',
#   'pertempuran hebat adalah lawang-sewu hebat',
#   'pertempuran yang hebat hebat',
#   'lawang-sewu yang hebat terdapat landmark lokasi',
#   'lokasi yang hebat memiliki pemuda hebat',
#   'semarang hebat menjadi jalan yang hebat',
#   'semarang yang hebat sebagai landmark',
#   'landmark yang hebat di pemuda yang hebat',
#   'jalan hebat sebagai lawang-sewu pemuda']}
