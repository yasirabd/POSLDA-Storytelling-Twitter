# %%
import pandas as pd
import numpy as np
import numpy.random as nr

# %%
document1 = {0: [['memotret/VBT', 0.07],
                 ['akses/NN', 0.04],
                 ['pintu/NN', 0.03],
                 ['bawah/NN', 0.03],
                 ['tanah/NN', 0.02],
                 ['aji/NN', 0.01],
                 ['fox/NN', 0.01],
                 ['lemas/JJ', 0.01],
                 ['berbarengan/VBT', 0.01]],
             1: [['om/NN', 0.08],
                 ['ditutup/NN', 0.07],
                 ['lihat/VBT', 0.06],
                 ['basement/NN', 0.05],
                 ['berkeliling/VBI', 0.04],
                 ['memotret/VBT', 0.04],
                 ['lantai/NN', 0.03],
                 ['foto/NN', 0.01],
                 ['lelah/JJ', 0.01]]}

# %%
document = document1

# %% [markdown]
# # Grammar

# %%
import re, random
from collections import OrderedDict, defaultdict

# %%
NP = ['_NN', '_NNG', '_NNP']
VP = ['_VBT _NN', '_MD _VBT _NN', '_VBT _NN _DT', '_VBT _NN _SC _JJ', '_VBT _NN _JJ', 
      '_RB _VBT _NP', '_VBT _RB _JJ', '_VBT _NN _NN', '_SC _VBT _NP', '_VBI']

# %%
def get_list_tag(dict_words_by_tag):
    result = []
    for key in dict_words_by_tag:
        result.append(key)
    return result

# %%
def generate_base_grammar(list_tag):
    result = {}
    
    if '_VBT' not in list_tag:
        list_tag.append('_VBT')
    
    if '_VBI' not in list_tag:
        list_tag.append('_VBI')
#     print(list_tag)
    S = {"_S": ["_NP _VP"]}
    PP = {"_PP": ["_IN _NP"]}
    
    if '_JJ' in list_tag:
        NP_RULES = generate_NP(list_tag)
        NP = {"_NP": NP_RULES}
        if check_VP(list_tag):
            VP_RULES = ['_JJ'] + generate_VP(list_tag)
            VP = {"_VP": VP_RULES}
        else:
            VP = {"_VP": ['_JJ', '_PP']}

        for r in [S, NP, VP, PP]:
            result.update(r)
        return result
    else:
        NP_RULES = remove_JJ(generate_NP(list_tag))
        NP = {"_NP": NP_RULES}
        if check_VP(list_tag):
            VP_RULES = remove_JJ(generate_VP(list_tag))
            VP = {"_VP": VP_RULES}
        else:
            VP = {"_VP": ['_PP']}
            
        for r in [S, NP, VP, PP]:
            result.update(r)
        return result

def generate_NP(list_tag):
    result = []
    for tag in list_tag:
        for words in NP:
            if re.search(r'\b' + tag + r'\b', words):
                result.append(words)
    return list(OrderedDict.fromkeys(result))
    
def check_VP(list_tag):
    for tag in list_tag:
        if 'V' in tag:
            return True
    return False

def generate_VP(list_tag):
    result = []
    for tag in list_tag:
        for words in VP:
            if re.search(r'\b' + tag + r'\b', words):
                result.append(words)
    return list(OrderedDict.fromkeys(result))

def remove_JJ(list_tag):
    result = []
    for tag in list_tag:
        if '_JJ' in tag:
            continue
        else:
            result.append(tag)
    return result

# %%
def generate_words_grammar(dict_words_by_tag):
    result = {}
    IN = {"_IN": ['di', 'dengan', 'untuk']}
    CC = {"_CC": ['dan', 'mau']}
    SC = {"_SC": ['yang']}
    RB = {"_RB": ['sedang', 'sambil', 'masih', 'lagi']}
    DT = {"_DT": ['itu']}
    MD = {"_MD": ['bisa', 'telah', 'sudah']}
    ADD_VBT = {"_VBT": ['adalah', 'ingin', 'pengin']}
    ADD_VBI = {"_VBI": ['ada', 'suka']}
    
    WORDS = dict_words_by_tag
    if '_VBT' in WORDS:
        for word in ADD_VBT["_VBT"]:
            if word not in WORDS['_VBT']:
                WORDS['_VBT'].append(word)
    else:
        WORDS.update(ADD_VBT)
    
    if '_VBI' in WORDS:
        for word in ADD_VBI["_VBI"]:
            if word not in WORDS['_VBI']:
                WORDS['_VBI'].append(word)
    else:
        WORDS.update(ADD_VBI)  
            
    for r in [IN, CC, SC, RB, DT, MD, WORDS]:
        result.update(r)
    return result

# %%
def organize_words_by_tag(list_words):
    result = defaultdict(list)
    
    i = []
    for s in list_words:
        word, pwz = s[0], s[1]
        
        wrd = word.split('/')[0]
        tag = word.split('/')[1]
        result['_'+tag].append([wrd, pwz])
    return dict(result)

# %%
def split_word_pwz(dict_words_pwz_by_tag):
    dict_word_by_tag = defaultdict(list)
    dict_pwz_by_tag = defaultdict(list)
    
    for key, values in dict_words_pwz_by_tag.items():
        for data in values:
            word, pwz = data[0], data[1]
            dict_word_by_tag[key].append(word)
            dict_pwz_by_tag[key].append(pwz)
    return dict(dict_word_by_tag), dict(dict_pwz_by_tag)

# %%
def create_grammar(dict_words_by_topic):
    grammar = {}
    
    dict_words_pwz_by_tag = organize_words_by_tag(dict_words_by_topic)
    list_tag = get_list_tag(dict_words_pwz_by_tag)
    base_grammar = generate_base_grammar(list_tag)
    dict_word_by_tag, dict_pwz_by_tag = split_word_pwz(dict_words_pwz_by_tag)
    words_grammar = generate_words_grammar(dict_word_by_tag)
    
    for r in [base_grammar, words_grammar]:
        grammar.update(r)
    return grammar, dict_pwz_by_tag

# %%
def merge_two_dicts(x, y):
    z = x.copy()
    z.update(y)
    return z

# %%
def is_terminal(token):
    return token[0] != "_"

# %%
sys_random = random.SystemRandom()

def expand(grammar, tokens, dict_pwz_by_tag):
#     print(tokens)
    for i, token in enumerate(tokens):

        # skip over terminals
        if is_terminal(token): continue

        # if we get here, we found a non-terminal token
        # so we need to choose a replacement at random
        replacement = sys_random.choice(grammar[token])
        
        if replacement == '_NN':
            weight = [x/sum(dict_pwz_by_tag['_NN']) for x in dict_pwz_by_tag['_NN']]
            replacement = nr.choice(grammar['_NN'], p=weight)
            print(weight)
#             print(grammar['_NN'], weight)
            
        if is_terminal(replacement):
            tokens[i] = replacement
        else:
            tokens = tokens[:i] + replacement.split() + tokens[(i+1):]
       
        # now call expand on the new list of tokens
        return expand(grammar, tokens, dict_pwz_by_tag)

    # if we get here we had all terminals and are done
    return tokens

# %%
def generate_sentence(grammar, dict_pwz_by_tag):
    return expand(grammar, ["_S"], dict_pwz_by_tag)

# %%
def create_sentences_from_data(dict_data):
    result = {}
    for topic, words in dict_data.items():
        sentence = []
        grammar, dict_pwz_by_tag = create_grammar(words)
        print(grammar)
        for s in range(100):
            sentence.append(' '.join(generate_sentence(grammar, dict_pwz_by_tag)))
        result = merge_two_dicts(result, {topic: sentence})
    return result

# %%
dict_story = create_sentences_from_data(document)
# Out:
# {'_S': ['_NP _VP'], '_NP': ['_NN'], '_VP': ['_JJ', '_VBT _NN', '_MD _VBT _NN', '_VBT _NN _DT', '_VBT _NN _SC _JJ', '_VBT _NN _JJ', '_RB _VBT _NP', '_VBT _RB _JJ', '_VBT _NN _NN', '_SC _VBT _NP', '_VBI'], '_PP': ['_IN _NP'], '_IN': ['di', 'dengan', 'untuk'], '_CC': ['dan', 'mau'], '_SC': ['yang'], '_RB': ['sedang', 'sambil', 'masih', 'lagi'], '_DT': ['itu'], '_MD': ['bisa', 'telah', 'sudah'], '_VBT': ['memotret', 'berbarengan', 'adalah', 'ingin', 'pengin'], '_NN': ['akses', 'pintu', 'bawah', 'tanah', 'aji', 'fox'], '_JJ': ['lemas'], '_VBI': ['ada', 'suka']}
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# [0.2857142857142857, 0.21428571428571425, 0.21428571428571425, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]
# {'_S': ['_NP _VP'], '_NP': ['_NN'], '_VP': ['_JJ', '_VBT _NN', '_MD _VBT _NN', '_VBT _NN _DT', '_VBT _NN _SC _JJ', '_VBT _NN _JJ', '_VBT _NN _NN', '_RB _VBT _NP', '_VBT _RB _JJ', '_SC _VBT _NP', '_VBI'], '_PP': ['_IN _NP'], '_IN': ['di', 'dengan', 'untuk'], '_CC': ['dan', 'mau'], '_SC': ['yang'], '_RB': ['sedang', 'sambil', 'masih', 'lagi'], '_DT': ['itu'], '_MD': ['bisa', 'telah', 'sudah'], '_NN': ['om', 'ditutup', 'basement', 'lantai', 'foto'], '_VBT': ['lihat', 'memotret', 'adalah', 'ingin', 'pengin'], '_VBI': ['berkeliling', 'ada', 'suka'], '_JJ': ['lelah']}
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]
# [0.3333333333333333, 0.2916666666666667, 0.20833333333333331, 0.12499999999999999, 0.041666666666666664]

# %%
dict_story
# Out:
# {0: ['akses sudah adalah pintu',
#   'akses lemas',
#   'aji pengin lagi lemas',
#   'akses masih ingin bawah',
#   'akses ingin bawah itu',
#   'tanah berbarengan aji lemas',
#   'pintu adalah sambil lemas',
#   'bawah ada',
#   'akses ada',
#   'bawah memotret masih lemas',
#   'tanah lemas',
#   'fox berbarengan masih lemas',
#   'pintu memotret bawah aji',
#   'tanah pengin sedang lemas',
#   'pintu sedang ingin pintu',
#   'pintu berbarengan aji itu',
#   'aji memotret aji lemas',
#   'pintu ingin pintu bawah',
#   'akses lemas',
#   'aji yang adalah pintu',
#   'pintu yang ingin akses',
#   'akses ingin fox yang lemas',
#   'aji suka',
#   'akses memotret akses itu',
#   'pintu lagi pengin akses',
#   'tanah masih adalah pintu',
#   'tanah ingin pintu yang lemas',
#   'akses sambil pengin aji',
#   'tanah lemas',
#   'tanah lemas',
#   'akses adalah lagi lemas',
#   'tanah ada',
#   'akses adalah fox lemas',
#   'akses bisa berbarengan fox',
#   'pintu masih adalah pintu',
#   'pintu lemas',
#   'aji ingin fox pintu',
#   'pintu yang memotret bawah',
#   'tanah adalah pintu yang lemas',
#   'pintu yang berbarengan pintu',
#   'tanah memotret fox fox',
#   'akses memotret lagi lemas',
#   'tanah berbarengan fox lemas',
#   'fox yang ingin tanah',
#   'akses bisa ingin tanah',
#   'bawah lemas',
#   'aji memotret aji lemas',
#   'tanah sedang ingin bawah',
#   'bawah pengin fox',
#   'bawah adalah pintu yang lemas',
#   'akses adalah aji itu',
#   'akses ingin bawah yang lemas',
#   'pintu lemas',
#   'bawah ada',
#   'bawah sedang berbarengan pintu',
#   'fox yang memotret bawah',
#   'bawah berbarengan pintu yang lemas',
#   'bawah adalah akses lemas',
#   'akses ada',
#   'bawah adalah aji yang lemas',
#   'fox sambil adalah akses',
#   'tanah ada',
#   'akses pengin tanah yang lemas',
#   'bawah sedang berbarengan tanah',
#   'tanah adalah fox yang lemas',
#   'pintu ingin akses tanah',
#   'pintu yang ingin akses',
#   'akses memotret pintu',
#   'bawah berbarengan tanah itu',
#   'akses bisa adalah tanah',
#   'bawah yang pengin bawah',
#   'tanah memotret tanah lemas',
#   'pintu berbarengan masih lemas',
#   'bawah memotret tanah yang lemas',
#   'bawah pengin aji yang lemas',
#   'pintu masih berbarengan tanah',
#   'tanah yang memotret pintu',
#   'tanah suka',
#   'tanah sambil adalah bawah',
#   'akses lemas',
#   'fox yang memotret bawah',
#   'tanah lemas',
#   'tanah ada',
#   'aji berbarengan fox lemas',
#   'pintu sambil pengin akses',
#   'bawah pengin pintu itu',
#   'akses ingin aji itu',
#   'tanah ingin lagi lemas',
#   'akses bisa ingin bawah',
#   'akses ada',
#   'tanah ada',
#   'tanah adalah tanah akses',
#   'akses yang pengin pintu',
#   'akses suka',
#   'bawah ada',
#   'akses adalah lagi lemas',
#   'akses pengin pintu yang lemas',
#   'tanah lagi pengin tanah',
#   'aji berbarengan aji',
#   'tanah sambil memotret akses'],
#  1: ['ditutup adalah basement lelah',
#   'basement lelah',
#   'basement lelah',
#   'ditutup bisa lihat om',
#   'om memotret om',
#   'lantai memotret sedang lelah',
#   'basement adalah lantai',
#   'basement pengin lantai',
#   'ditutup ingin om',
#   'foto berkeliling',
#   'ditutup sambil lihat om',
#   'ditutup masih lihat ditutup',
#   'ditutup ingin ditutup',
#   'om lelah',
#   'om lihat masih lelah',
#   'om pengin ditutup yang lelah',
#   'lantai yang adalah basement',
#   'ditutup lihat om lelah',
#   'basement lihat ditutup lelah',
#   'om yang adalah ditutup',
#   'foto yang ingin om',
#   'ditutup berkeliling',
#   'lantai ingin ditutup itu',
#   'basement sudah pengin foto',
#   'ditutup lihat sambil lelah',
#   'lantai yang lihat ditutup',
#   'lantai ingin basement',
#   'ditutup ada',
#   'foto ingin masih lelah',
#   'ditutup adalah lantai lelah',
#   'om pengin ditutup lelah',
#   'basement lihat masih lelah',
#   'basement berkeliling',
#   'ditutup memotret masih lelah',
#   'basement ingin om lelah',
#   'basement ingin om om',
#   'om pengin lantai ditutup',
#   'ditutup yang memotret om',
#   'om bisa pengin ditutup',
#   'basement adalah basement',
#   'om yang memotret om',
#   'ditutup lagi ingin ditutup',
#   'lantai telah adalah foto',
#   'om sedang pengin om',
#   'om lelah',
#   'om adalah basement lelah',
#   'om memotret sambil lelah',
#   'basement ingin basement lantai',
#   'ditutup pengin lagi lelah',
#   'om ingin lantai lelah',
#   'lantai pengin om yang lelah',
#   'lantai yang lihat ditutup',
#   'ditutup lihat foto itu',
#   'ditutup sudah pengin om',
#   'om adalah foto lelah',
#   'lantai adalah lantai itu',
#   'ditutup yang adalah ditutup',
#   'ditutup ada',
#   'om lelah',
#   'om pengin lantai yang lelah',
#   'lantai adalah basement',
#   'ditutup sudah memotret basement',
#   'foto adalah om',
#   'ditutup ingin lagi lelah',
#   'om yang adalah ditutup',
#   'basement sudah ingin basement',
#   'foto yang ingin om',
#   'basement telah pengin ditutup',
#   'ditutup lihat om lelah',
#   'ditutup bisa memotret foto',
#   'om pengin ditutup',
#   'om pengin lantai lelah',
#   'om masih adalah om',
#   'basement masih ingin om',
#   'om ingin lantai itu',
#   'om lihat ditutup itu',
#   'om lihat ditutup lelah',
#   'basement yang pengin basement',
#   'om lelah',
#   'om memotret lagi lelah',
#   'basement ingin lantai om',
#   'ditutup lelah',
#   'ditutup pengin basement basement',
#   'ditutup yang pengin basement',
#   'om ada',
#   'basement memotret basement lelah',
#   'basement adalah foto itu',
#   'lantai yang adalah lantai',
#   'lantai lelah',
#   'om ada',
#   'foto memotret om yang lelah',
#   'lantai sudah memotret ditutup',
#   'om lelah',
#   'ditutup ingin om',
#   'ditutup sudah pengin basement',
#   'ditutup ingin om',
#   'ditutup lelah',
#   'om adalah masih lelah',
#   'om ingin foto itu',
#   'basement lelah']}
